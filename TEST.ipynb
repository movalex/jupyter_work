# %%
import random
horses = [random.randint(3456,787934) for i in range(25)]

# %%
count = 0
for horse in horses:

# %%
def isprime(n):
    if n == 2:
        return True
    if n % 2 == 0:
        return False
    for i in range(3, int(n**0.5 + 1), 2):
        if n % i == 0:
            return False
    return True


def buildPrimes(n):
    return (i for i in range(2, n + 1) if isprime(i))


def primeFactors(n):
    primes = []
    x = n
    pi = 1
    for i in buildPrimes(int(n**0.5)):
        c = 0
        if x % i == 0:
            while x % i == 0:
                pi = pi * i
                c += 1
                x /= i
            primes.append((str(i)+"**"+str(c)).replace(r"**1",""))
            c = 0
            other = n // pi
            if isprime(other):
                if x % other == 0:
                    while x % other == 0:
                        c += 1
                        x /= other
                    primes.append((str(other)+"**"+str(c)).replace(r"**1",""))
    if not primes:
        return f"({n})"
    return f"({')('.join(primes)})"

# %%
primeFactors(33)

# %%
isprime(17)

# %%
n = list(range(1,7))
n

# %%
pages = list(zip(n[0::2], n[1::2]))
pages

# %%
# ?zip

# %%
# https://www.hackerrank.com/challenges/drawing-book/problem?utm_campaign=challenge-recommendation&utm_medium=email&utm_source=24-hour-campaign

def pageCount(n, p):
    pagelist = list(range(n+1))
    pagelist[0] = 'firstPage'
    if n % 2 == 0:
        pagelist.append('lastPage')
    pages = list(zip(pagelist[0::2], pagelist[1::2]))
    print(pages)
    mid = len(pages) // 2
    print(pages[mid])
    for take in pages:
        if p in take:
            place = pages.index(take)
    if place < mid:
        return place
    return (len(pages)-1) - place
pageCount(36,16)

# %%
class Parent():
    def __init__(self):
        self.__private = 'foo'
        self.protected = 'bar'
        
class Child(Parent):
    @property
    def get_protected(self):
        return self.protected
    @property
    def get_private(self):
        return self.__private

# %%
c = Child()

# %%
c.get_protected
# Out:
# 'bar'

# %%
c.get_private #won't work
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-125-9e8c7d8aafd0> in <module>()
# ----> 1 c.get_private #won't work
#
# <ipython-input-120-6012c8fd9124> in get_private(self)
#      10     @property
#      11     def get_private(self):
# ---> 12         return self.__private
#      13
#
# AttributeError: 'Child' object has no attribute '_Child__private'

# %%
import ipyvolume.pylab as p3

import numpy as np
import ipyvolume.datasets
stream = ipyvolume.datasets.animated_stream.fetch()
print("shape of steam data", stream.data.shape) # first dimension contains x, y, z, vx, vy, vz, then time, then particle


fig = p3.figure()
q = p3.quiver(*stream.data[:,0:50,:200], color='red', size=7)
p3.style.use('dark')
p3.animation_control(q, interval=200)
p3.show()
# Out:
# shape of steam data (6, 200, 1250)
# ...

# %%
import ipyvolume as ipv
import numpy as np
def set_view(figure, framenr, fraction):
    ipv.view(fraction*360, (fraction - 0.5) * 180, distance=2 + fraction*2)
    s.size = size * (2+0.5*np.sin(fraction * 6 * np.pi))
ipv.movie('wave.gif', set_view, fps=20, frames=40)
# Out:
# Output()
# NameErrorTraceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/ipyvolume/pylab.py in movie(f, function, fps, frames, endpoint, cmd_template_ffmpeg, cmd_template_gif, gif_loop)
#     790         with output:
#     791             fraction = i / (frames - 1. if endpoint else frames)
# --> 792             function(fig, i, fraction)
#     793             frame_filename = os.path.join(tempdir, "frame-%05d.png" % i)
#     794             savefig(frame_filename, output_widget=output)
#
# <ipython-input-10-a3c5f062353e> in set_view(figure, framenr, fraction)
#       3 def set_view(figure, framenr, fraction):
#       4     ipv.view(fraction*360, (fraction - 0.5) * 180, distance=2 + fraction*2)
# ----> 5     s.size = size * (2+0.5*np.sin(fraction * 6 * np.pi))
#       6 ipv.movie('wave.gif', set_view, fps=20, frames=40)
#
# NameError: name 'size' is not defined
# NameErrorTraceback (most recent call last)
# ...

# %%
s = 1/2**0.5
# 4 vertices for the tetrahedron
x = np.array([1.,  -1, 0,  0])
y = np.array([0,   0, 1., -1])
z = np.array([-s, -s, s,  s])
# and 4 surfaces (triangles), where the number refer to the vertex index
triangles = [(0, 1, 2), (0, 1, 3), (0, 2, 3), (1,3,2)]

# %%
ipv.figure()
# we draw the tetrahedron
mesh = ipv.plot_trisurf(x, y, z, triangles=triangles, color='orange')
# and also mark the vertices
ipv.scatter(x, y, z, marker='sphere', color='blue')
ipv.xyzlim(-2, 2)
ipv.show()
